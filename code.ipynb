1 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.2 MB 11.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 12.6 MB/s eta 0:00:00
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/10.0 MB 9.1 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/10.0 MB 8.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.2/10.0 MB 7.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/10.0 MB 7.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.0 MB 6.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.0 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 7.1 MB/s eta 0:00:00
# Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Downloading soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 9.7 MB/s eta 0:00:00
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.0-cp312-cp312-win_amd64.whl (75 kB)
# Downloading numba-0.61.0-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --------------------------------- ------ 2.4/2.8 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 11.0 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading soxr-0.5.0.post1-cp312-abi3-win_amd64.whl (164 kB)
# Downloading tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 11.4 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 13.3 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp312-cp312-win_amd64.whl (30.3 MB)
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    - -------------------------------------- 1.3/30.3 MB 6.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.7/30.3 MB 8.7 MB/s eta 0:00:04
#    ------- -------------------------------- 5.5/30.3 MB 8.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 7.9/30.3 MB 9.5 MB/s eta 0:00:03
#    ------------- -------------------------- 10.5/30.3 MB 10.2 MB/s eta 0:00:02
#    --------------- ------------------------ 11.8/30.3 MB 9.8 MB/s eta 0:00:02
#    ------------------ --------------------- 13.9/30.3 MB 9.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 16.8/30.3 MB 10.3 MB/s eta 0:00:02
#    ------------------------ --------------- 18.4/30.3 MB 10.1 MB/s eta 0:00:02
#    -------------------------- ------------- 20.2/30.3 MB 10.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 22.0/30.3 MB 10.0 MB/s eta 0:00:01
#    ------------------------------- -------- 23.6/30.3 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 26.2/30.3 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------ --- 28.0/30.3 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  29.6/30.3 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 30.3/30.3 MB 9.5 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 6.0 MB/s eta 0:00:00
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: mpmath, sympy, soxr, safetensors, regex, pycparser, networkx, msgpack, llvmlite, lazy-loader, audioread, torch, pooch, numba, cffi, tokenizers, soundfile, transformers, librosa
# Successfully installed audioread-3.0.1 cffi-1.17.1 lazy-loader-0.4 librosa-0.10.2.post1 llvmlite-0.44.0 mpmath-1.3.0 msgpack-1.1.0 networkx-3.4.2 numba-0.61.0 pooch-1.8.2 pycparser-2.22 regex-2024.11.6 safetensors-0.5.3 soundfile-0.13.1 soxr-0.5.0.post1 sympy-1.13.1 tokenizers-0.21.0 torch-2.6.0 transformers-4.49.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import librosa
import soundfile as sf
from transformers import pipeline
import os
os.environ["PATH"] += os.pathsep + "C:/ffmpeg-6.0/bin"  # Update this path as per your installation

# %%
# Check if GPU is available, otherwise use CPU
device = 0 if torch.cuda.is_available() else "cpu"

# Load the Whisper model from Hugging Face
model_name = "openai/whisper-large-v3"
whisper_pipe = pipeline("automatic-speech-recognition", model=model_name, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32, device=device)

print(f"Model loaded on: {'GPU' if torch.cuda.is_available() else 'CPU'}")
# Out:
# c:\Users\vishw\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Model loaded on: CPU

# %%
def transcribe_audio(audio_path):
    # Load the audio file
    audio, sr = librosa.load(audio_path, sr=16000)  # Resample to 16kHz if needed
    temp_wav = "temp.wav"
    sf.write(temp_wav, audio, sr)  # Convert to WAV format

    # Transcribe the audio
    result = whisper_pipe(temp_wav)
    return result["text"]

# %%
# Provide the path to your MP3 file
audio_file = "C:\\Users\\vishw\\Downloads\\harvard.mp3"

# Transcribe the audio
transcription = transcribe_audio(audio_file)

# Print the transcription
print("Transcribed Text:\n", transcription)
# Out:
# Transcribed Text:
#   the stale smell of old beer lingers it takes heat to bring out the odor a cold dip restores health and zest a salt pickle tastes fine with ham tacos al pastor are my favorite a zestful food is the hot cross bun
